# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
caminho = "/content/drive/MyDrive/atividade_didatica/material-didatico/analise-de-dados/banco-itens/transformacao/va_discreta"
dados = pd.read_excel(f"{caminho}/transformacao_discreta.xlsx")
dados
# Out:
#     suporte     fp
# 0        -6  0.079
# 1        -5  0.043
# 2        -4  0.018
# 3        -3  0.096
# 4        -2  0.047
# 5        -1  0.035
# 6         0  0.201
# 7         1  0.250
# 8         2  0.031
# 9         3  0.020
# 10        4  0.077
# 11        5  0.077
# 12        6  0.028

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   suporte  13 non-null     int64
#  1   fp       13 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 336.0 bytes

# %%
n = (dados.shape[0] - 1) /2
n
# Out:
# 6.0

# %%
suporte_y = [k ** 2 for k in range(int(n)+1)]
suporte_y
len(suporte_y)
[k for k in range(int(n)+1)]
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
fp_y = [dados.fp[k-1] + dados.fp[n + 1 + k - 1] for k in range(1, int(n)+1)]
fp_y.insert(0, dados.fp[int(n)])
print(fp_y)
print(np.sum(fp_y))
# Out:
# [0.201, 0.329, 0.074, 0.038, 0.173, 0.124, 0.063]
# 1.002

# %%
df_resposta = pd.DataFrame({
    "suporte": suporte_y,
    "fp": fp_y
})
df_resposta
# Out:
#    suporte     fp
# 0        0  0.201
# 1        1  0.329
# 2        4  0.074
# 3        9  0.038
# 4       16  0.173
# 5       25  0.124
# 6       36  0.063

# %%
df_resposta.to_excel(f"{caminho}/resposta.xlsx")
