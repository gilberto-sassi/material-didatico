# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
caminho = "/content/drive/MyDrive/atividade_didatica/material-didatico/probabilidade-1/banco-itens/transformacao/va_discreta"
dados = pd.read_excel(f"{caminho}/dados_atv.xlsx")
dados
# Out:
#     suporte     fp
# 0        -8  0.029
# 1        -7  0.044
# 2        -6  0.101
# 3        -5  0.084
# 4        -4  0.173
# 5        -3  0.015
# 6        -2  0.037
# 7        -1  0.053
# 8         0  0.115
# 9         1  0.055
# 10        2  0.049
# 11        3  0.020
# 12        4  0.063
# 13        5  0.012
# 14        6  0.035
# 15        7  0.053
# 16        8  0.062

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   suporte  17 non-null     int64
#  1   fp       17 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 400.0 bytes

# %%
n = (dados.shape[0] - 1) /2
n
# Out:
# 8.0

# %%
suporte_y = [k ** 4 for k in range(int(n)+1)]
suporte_y
len(suporte_y)
[k for k in range(int(n)+1)]
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
fp_y = [dados.fp[n - k] + dados.fp[n + k] for k in range(1, int(n)+1)]
fp_y.insert(0, dados.fp[int(n)])
print(fp_y)
print(np.sum(fp_y))
# Out:
# [0.115, 0.108, 0.086, 0.035, 0.236, 0.096, 0.136, 0.097, 0.091]
# 0.9999999999999999

# %%
df_resposta = pd.DataFrame({
    "suporte": suporte_y,
    "fp": fp_y
})
df_resposta
# Out:
#    suporte     fp
# 0        0  0.115
# 1        1  0.108
# 2       16  0.086
# 3       81  0.035
# 4      256  0.236
# 5      625  0.096
# 6     1296  0.136
# 7     2401  0.097
# 8     4096  0.091

# %%
df_resposta.to_excel(f"{caminho}/resposta-python.xlsx")
